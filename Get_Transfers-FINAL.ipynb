# %%
## Purpose: Download transfers for the 9 leagues from the football API. Transfers from:
## EPL, MLS, Bundesliga, La Liga, Ligue 1, Liga MX, Liga Nos, Premier Liga, Serie A

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ## Set up API Info

# %%
headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "835fa8219cmsh874166c2864ff34p19eddcjsneace1fe07ff5"
    }

# %%
## initialize nested dictionary to hold each league, league id, and list of teams
## color will be used for visual purposes. Add later
league_info = {
    'Premier League': {
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    'MLS': {
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    'Bundesliga': {
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    'La Liga': {
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    'Ligue 1': {
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    'Liga MX': {
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    'Liga Nos': { ## also known as Premeira Liga - Portugal
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    'Premier Liga': {
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    'Serie A': {
        'teams': '',
        'code': '',
        'country': '',
        'color': ''
    },
    
}

# %% [markdown]
# ## Create functions to get league ids, team ids, and transfers

# %%
## Function 1: Get league ids from country
## Easiest to just print out a list and manuall add the leagues to nested dictionary
def get_leagues(countries):
    
    for country in countries:
        url = "https://api-football-v1.p.rapidapi.com/v2/leagues/country/" + str(country) + '/2020'
        response = requests.request("GET", url, headers=headers)
        obj = response.json()
        leagues = obj['api']['leagues']
        
        print(country)
        
        for league in leagues:
            print(str(league['league_id']) + ' ' + str(league['name'])) 
            
        print('\n')

# %%
## Get leagues from 9 countries of interest
get_leagues(['Mexico', 'England', 'France', 'Germany', 'Portugal', 'USA', 'Russia', 'Spain', 'Italy' ])
# Out:
# Mexico
# 2656 Liga MX
# 2767 Ascenso MX
# 2786 Copa por México
# 2839 Liga MX Femenil
#
#
# England
# 2725 Community Shield
# 2745 FA WSL
# 2781 League Cup
# 2790 Premier League
# 2791 FA Cup
# 2792 EFL Trophy
# 2794 Championship
# 2796 League Two
# 2800 FA Trophy
# 2803 League One
# 2830 Non League Div One - Isthmian North
# 2831 Non League Premier - Southern
# 2836 Community Shield Women
#
#
# France
# 2652 Ligue 2
# 2664 Ligue 1
# 2665 National
# 2668 Feminine Division 1
# 2744 National 2 - Group A
#
#
# Germany
# 2677 DFB Pokal
# 2681 Women Bundesliga
# 2692 U19 Bundesliga
# 2738 Regionalliga - West
# 2743 Bundesliga 2
# 2751 Super Cup
# 2755 Bundesliga 1
# 2795 Liga 3
# 2821 Regionalliga - Nord
# 2822 Regionalliga - Nordost
# 2823 Regionalliga - SudWest
#
#
# Portugal
# 2750 Super Cup
# 2826 Primeira Liga
# 2827 Liga de Honra
#
#
# USA
# 1264 Major League Soccer
# 1328 USL Championship
# 1355 US Open Cup
# 1379 USL League Two
# 1391 NWSL Women
# 1406 USL League One
# 2648 NWSL Women - Challenge Cup
# 2760 NISA
#
#
# Russia
# 2672 Football National League
# 2679 Premier League
# 2707 Cup
# 2732 Supreme Division Women
# 2733 PFL - Center
# 2734 PFL - South
# 2735 PFL - West
# 2736 PFL - Ural-Povolzhye
# 2787 Super Cup
#
#
# Spain
# 2833 Primera Division
# 2847 Segunda Division
#
#
# Italy
# 2798 Serie A Women
# 2857 Serie A

# %%
## add top flight league info to dictionary
league_info['Liga MX']['code'] = 2656
league_info['Liga MX']['country'] = 'Mexico'

league_info['MLS']['code'] = 1264
league_info['MLS']['country'] = 'United States'

league_info['Premier League']['code'] = 2790
league_info['Premier League']['country'] = 'England'

league_info['Bundesliga']['code'] = 2755
league_info['Bundesliga']['country'] = 'Germany'

league_info['Ligue 1']['code'] = 2664
league_info['Ligue 1']['country'] = 'France'

league_info['Liga Nos']['code'] = 2826
league_info['Liga Nos']['country'] = 'Portugal'

league_info['Premier Liga']['code'] = 2679
league_info['Premier Liga']['country'] = 'Russia'

league_info['La Liga']['code'] = 2833
league_info['La Liga']['country'] = 'Spain'

league_info['Serie A']['code'] = 2857
league_info['Serie A']['country'] = 'Italy'

league_info
# Out:
# {'Premier League': {'teams': '',
#   'code': 2790,
#   'country': 'England',
#   'color': ''},
#  'MLS': {'teams': '', 'code': 1264, 'country': 'United States', 'color': ''},
#  'Bundesliga': {'teams': '', 'code': 2755, 'country': 'Germany', 'color': ''},
#  'La Liga': {'teams': '', 'code': 2833, 'country': 'Spain', 'color': ''},
#  'Ligue 1': {'teams': '', 'code': 2664, 'country': 'France', 'color': ''},
#  'Liga MX': {'teams': '', 'code': 2656, 'country': 'Mexico', 'color': ''},
#  'Liga Nos': {'teams': '', 'code': 2826, 'country': 'Portugal', 'color': ''},
#  'Premier Liga': {'teams': '', 'code': 2679, 'country': 'Russia', 'color': ''},
#  'Serie A': {'teams': '', 'code': 2857, 'country': 'Italy', 'color': ''}}

# %%
## Function 2: Get list of teams from league id. Create a dictionary to keep the teams and their ids in
team_dict = {}

def get_teams(league):
    league_id = league_info[league]['code']
    
    url = "https://api-football-v1.p.rapidapi.com/v2/teams/league/" + str(league_id)
    response = requests.request("GET", url, headers=headers)
    obj = response.json()
    
    teams = obj['api']['teams']
    
    ## create a list of team_ids to add to the league_info dict
    team_ids = []
    for team in teams:
        team_ids.append(team['team_id'])
        
        ## add each team and id to team_dict
        team_dict[team['name']]  = team['team_id'] 
        #team_dict[str(team['team_id'])] = team_dict[team['name']]
    
    ## add teams to leagues
    league_info[league]['teams'] = team_ids

    return teams

# %%
for key in league_info.keys():
    get_teams(key)

# %%
## Function 3: Get transfers from team id

def get_transfers(team_ids):
    
    df = pd.DataFrame()
    
    for team_id in team_ids:
        url = "https://api-football-v1.p.rapidapi.com/v2/transfers/team/" + str(team_id)
        response = requests.request("GET", url, headers=headers)
        obj = response.json()
        transfers = obj['api']['transfers']
        df = df.append(transfers)

    return df

# %%
## create dataframe of transfers
transfers = pd.DataFrame()
for key in league_info.keys():
    print(league_info[key]['teams'])
    transfers = transfers.append(get_transfers(league_info[key]['teams']))

## undo nested dictionaries
transfers['team_in_id'] = transfers['team_in'].apply(lambda x: x['team_id'])
transfers['team_in_name'] = transfers['team_in'].apply(lambda x: x['team_name'])
transfers['team_out_id'] = transfers['team_out'].apply(lambda x: x['team_id'])
transfers['team_out_name'] = transfers['team_out'].apply(lambda x: x['team_name'])
transfers = transfers.drop(['team_in', 'team_out'], axis = 1)
# Out:
# [44, 33, 52, 41, 36, 42, 40, 63, 50, 66, 47, 45, 60, 46, 48, 34, 51, 49, 62, 39]
# [1615, 1610, 1614, 1609, 1600, 1605, 1596, 1601, 1598, 1606, 1597, 1599, 9569, 1608, 1603, 1611, 1613, 1604, 1602, 2242, 1595, 1607, 1616, 9568, 1617, 1612]
# [157, 174, 165, 163, 173, 164, 161, 168, 169, 188, 182, 170, 192, 167, 162, 159, 172, 160]
# [542, 543, 529, 797, 545, 538, 724, 727, 715, 531, 541, 546, 532, 539, 720, 548, 533, 726, 530, 536]
# [97, 95, 79, 94, 89, 77, 78, 83, 81, 1063, 91, 93, 92, 106, 84, 116, 82, 80, 85, 112]
# [2295, 2285, 2286, 2290, 2282, 2281, 2292, 2287, 2291, 2298, 2288, 2280, 2279, 2283, 2314, 14002, 2278, 2289]
# [242, 211, 225, 222, 227, 214, 224, 221, 215, 231, 212, 217, 216, 234, 228, 762, 218, 226]
# [1083, 597, 2008, 779, 558, 2012, 1077, 1085, 2010, 596, 1084, 1088, 1078, 621, 1994, 555]
# [506, 505, 502, 503, 495, 501, 496, 498, 487, 499, 489, 500, 523, 492, 488, 490, 494, 515, 504, 497]

# %%
transfers
# Out:
#      lastUpdate  player_id                   player_name transfer_date  \
# 0    1587248847     230945               Nick Liversedge    2013-09-16
# 1    1587248847     230945               Nick Liversedge    2013-07-01
# 2    1596440639      19115            B. Peacock-Farrell    2019-08-02
# 3    1598675887     102734               Richard Chaplow    2005-01-01
# 4    1598675893      87911               Martin Paterson    2013-07-01
# 5    1598675893      87911               Martin Paterson    2008-08-01
# 6    1598712724      18923                     S. Defour    2019-09-02
# 7    1598712724      18923                     S. Defour    2016-08-16
# 8    1598842162       6814                     B. Wilson    2016-07-01
# 9    1598842162       6814                     B. Wilson    2016-03-24
# 10   1598863000       1747       Scott Nathaniel Arfield    2018-06-09
# 11   1598863000       1747       Scott Nathaniel Arfield    2013-07-19
# 12   1598863307      44840                Marvin Bartley    2013-08-01
# 13   1598863307      44840                Marvin Bartley    2011-02-02
# 14   1598863337      44889                  Brian Easton    2012-09-06
# 15   1598863337      44889                  Brian Easton    2010-01-30
# 16   1598863337      44889                  Brian Easton    2009-07-14
# 17   1598863396      20067      Christopher Michael Long    2018-07-20
# 18   1598863396      20067      Christopher Michael Long    2017-07-28
# 19   1598863396      20067      Christopher Michael Long    2017-07-01
# 20   1598863396      20067      Christopher Michael Long    2017-01-30
# 21   1598863396      20067      Christopher Michael Long    2016-08-12
# 22   1598881513      60043  André Stéphane Bikey-Amougou    2012-03-23
# 23   1598881513      60043  André Stéphane Bikey-Amougou    2009-08-19
# 24   1598882654      19151                  Tyrone Mears    2011-07-29
# 25   1598885300      28607                  Gábor Király    2009-08-01
# 26   1598885300      28607                  Gábor Király    2009-02-01
# 27   1598885300      28607                  Gábor Király    2007-07-01
# 28   1598885647      18909                   A. Legzdins    2017-08-08
# 29   1598885649      18925                     A. Lennon    2018-01-23
# ..          ...        ...                           ...           ...
# 636  1599108578      31389               Norbert Gyömbér    2017-08-31
# 637  1599108578      31389               Norbert Gyömbér    2017-07-01
# 638  1599108578      31389               Norbert Gyömbér    2017-02-16
# 639  1599108578      31389               Norbert Gyömbér    2016-08-12
# 640  1599108578      31389               Norbert Gyömbér    2016-07-01
# 641  1599108578      31389               Norbert Gyömbér    2015-08-20
# 642  1599108840      31058                    Salih Uçan    2016-07-01
# 643  1599108840      31058                    Salih Uçan    2014-07-06
# 644  1599108955        969                    Tin Jedvaj    2015-01-20
# 645  1599108955        969                    Tin Jedvaj    2014-07-01
# 646  1599108955        969                    Tin Jedvaj    2013-07-11
# 647  1599109092       8526               Petar Golubović    2017-08-31
# 648  1599109092       8526               Petar Golubović    2017-07-01
# 649  1599109092       8526               Petar Golubović    2015-07-17
# 650  1599109092       8526               Petar Golubović    2015-07-01
# 651  1599109092       8526               Petar Golubović    2014-08-26
# 652  1599109092       8526               Petar Golubović    2014-07-01
# 653  1599109092       8526               Petar Golubović    2014-01-31
# 654  1599109092       8526               Petar Golubović    2014-01-30
# 655  1599109329      63546     Alan Kevin Méndez Olivera    2018-07-17
# 656  1599109329      63546     Alan Kevin Méndez Olivera    2017-08-09
# 657  1599109329      63546     Alan Kevin Méndez Olivera    2016-02-01
# 658  1599109329      63546     Alan Kevin Méndez Olivera    2015-01-07
# 659  1599109329      63546     Alan Kevin Méndez Olivera    2015-01-04
# 660  1599109639      43011        Mihai Alexandru Bălașa    2014-08-22
# 661  1599109639      43011        Mihai Alexandru Bălașa    2013-07-28
# 662  1599109640      31636                  Deian Boldor    2015-07-23
# 663  1599109640      31636                  Deian Boldor    2015-07-01
# 664  1599109640      31636                  Deian Boldor    2014-07-01
# 665  1599109640      31636                  Deian Boldor    2011-07-24
#
#        type  team_in_id         team_in_name  team_out_id  \
# 0      Loan      4694.0          Hyde United         44.0
# 1      Free        44.0              Burnley       7757.0
# 2    € 2.8M        44.0              Burnley         63.0
# 3    2.3M €        60.0            West Brom         44.0
# 4      Free        37.0         Huddersfield         44.0
# 5    1.9M €        44.0              Burnley       1340.0
# 6      Free       740.0              Antwerp         44.0
# 7      € 8M        44.0              Burnley        554.0
# 8      Free       940.0          Perth Glory         44.0
# 9      Loan      4686.0     Stockport County         44.0
# 10     Free       257.0              Rangers         44.0
# 11     Free        44.0              Burnley         37.0
# 12     Loan      1373.0        Leyton Orient         44.0
# 13   € 450K        44.0              Burnley         35.0
# 14     Free       253.0               Dundee         44.0
# 15     Loan       248.0  Hamilton Academical         44.0
# 16   € 400K        44.0              Burnley        248.0
# 17     Free      1336.0       Fleetwood Town         44.0
# 18     Loan      1337.0          Northampton         44.0
# 19      N/A        44.0              Burnley         68.0
# 20     Loan        68.0               Bolton         44.0
# 21     Loan      1336.0       Fleetwood Town         44.0
# 22     Loan        56.0         Bristol City         44.0
# 23   € 3.3M        44.0              Burnley         53.0
# 24   1.7M €        68.0               Bolton         44.0
# 25     Free       786.0      TSV 1860 Munich         44.0
# 26     Loan       168.0     Bayer Leverkusen         44.0
# 27     Free        44.0              Burnley         52.0
# 28      N/A        44.0              Burnley         54.0
# 29      N/A        44.0              Burnley         45.0
# ..      ...         ...                  ...          ...
# 636    Loan       508.0                 Bari        497.0
# 637     N/A       497.0              AS Roma       1085.0
# 638    Loan      1085.0        Akhmat Grozny        497.0
# 639    Loan       525.0              Pescara        497.0
# 640  € 1.5M       497.0              AS Roma       1580.0
# 641    Loan       497.0              AS Roma       1580.0
# 642     N/A       611.0           Fenerbahce        497.0
# 643    Loan       497.0              AS Roma        611.0
# 644    € 7M       168.0     Bayer Leverkusen        497.0
# 645    Loan       168.0     Bayer Leverkusen        497.0
# 646    € 5M       497.0              AS Roma        620.0
# 647     N/A       513.0               Novara        497.0
# 648     N/A       497.0              AS Roma        801.0
# 649    Loan       801.0                 Pisa        497.0
# 650     N/A       497.0              AS Roma       1589.0
# 651    Loan      1589.0            Pistoiese        497.0
# 652     N/A       497.0              AS Roma        513.0
# 653    Loan       513.0               Novara        497.0
# 654    € 1M       497.0              AS Roma       2633.0
# 655     N/A      3617.0              Karpaty        497.0
# 656    Loan      1585.0            Viterbese        497.0
# 657    Loan      1014.0             Lausanne        497.0
# 658    Loan       524.0              Perugia        497.0
# 659  € 1.5M       497.0              AS Roma       2348.0
# 660    Loan       501.0              Crotone        497.0
# 661     N/A       497.0              AS Roma        570.0
# 662     N/A         NaN                 None        497.0
# 663     N/A       497.0              AS Roma        525.0
# 664    Loan       525.0              Pescara        497.0
# 665     N/A       497.0              AS Roma      13431.0
#
#               team_out_name
# 0                   Burnley
# 1               Whitby Town
# 2                     Leeds
# 3                   Burnley
# 4                   Burnley
# 5                Scunthorpe
# 6                   Burnley
# 7                Anderlecht
# 8                   Burnley
# 9                   Burnley
# 10                  Burnley
# 11             Huddersfield
# 12                  Burnley
# 13              Bournemouth
# 14                  Burnley
# 15                  Burnley
# 16      Hamilton Academical
# 17                  Burnley
# 18                  Burnley
# 19                   Bolton
# 20                  Burnley
# 21                  Burnley
# 22                  Burnley
# 23                  Reading
# 24                  Burnley
# 25                  Burnley
# 26                  Burnley
# 27           Crystal Palace
# 28               Birmingham
# 29                  Everton
# ..                      ...
# 636                 AS Roma
# 637           Akhmat Grozny
# 638                 AS Roma
# 639                 AS Roma
# 640                 Catania
# 641                 Catania
# 642                 AS Roma
# 643              Fenerbahce
# 644                 AS Roma
# 645                 AS Roma
# 646           Dinamo Zagreb
# 647                 AS Roma
# 648                    Pisa
# 649                 AS Roma
# 650               Pistoiese
# 651                 AS Roma
# 652                  Novara
# 653                 AS Roma
# 654             OFK Beograd
# 655                 AS Roma
# 656                 AS Roma
# 657                 AS Roma
# 658                 AS Roma
# 659                 Penarol
# 660                 AS Roma
# 661      Viitorul Constanta
# 662                 AS Roma
# 663                 Pescara
# 664                 AS Roma
# 665  Elazığ Belediyespor SK
#
# [60766 rows x 9 columns]

# %%
## save transfers df to csv
#transfers.to_csv('D:/Learning/Python/Market_Values/transfers.csv', index = False)

# %%
## serialize dictionaries as json files and save to use later
import json

with open('D:/Learning/Python/Market_Values/league_info.json', 'w') as outfile:
    #json.dump(league_info, outfile, indent = 4)
    
with open('D:/Learning/Python/Market_Values/team_dict.json', 'w') as outfile:
    #json.dump(team_dict, outfile, indent = 4)
